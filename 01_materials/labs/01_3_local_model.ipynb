# %% [markdown]
# # LM Studio
#
#  LM Studio is a powerful platform designed for working with large language models (LLMs) on your local machine. It provides an intuitive interface for downloading, managing, and running a wide variety of open-source LLMs.
#
# A few characteristics of LM Studio are:
#
# + With LM Studio, users can experiment with different models, customize their settings, and interact with them in real time.
# + The platform supports both CPU and GPU acceleration, making it accessible for a range of hardware configurations.
# + LM Studio is ideal for developers, researchers, and enthusiasts who want to explore LLM capabilities without relying on cloud-based solutions.
#
# You can download and install LMStudio from [lmstudio.ai](https://lmstudio.ai/).
#
# ## LM Studio API
#
# An important characteristic in LM Studio is its support for OpenAI's API:
#
# + LM Studio accepts requests on several OpenAI endpoints and returns OpenAI-like response objects ([lmstudio.ai](https://platform.openai.com/docs/guides/prompt-engineering#message-roles-and-instruction-following)).
# + This means that we can reuse our code by pointing the local API using the `base_url` parameter.

# %% [markdown]
# ## Setup LM Studio
#
# + Download and install LM Studio from [lmstudio.ai](https://lmstudio.ai/).
# + Start the application.
# + Select a model to load:
#
#     - From the developer tab, you can select a model from the top bar.
#     - Select a model, for example, any model from the Qwen3 class of models.
#     - Start the server with the control on the top-left labelled "Status: Stopped" or "Status: Running".
#
#
# <img src="./img/01_lmstudio.png" height="400">

# %% [markdown]
# With the setup above, we can point to the local server as indicated below. The API works similarly to OpenAI; however, the underlying model runs locally and was not necessarily produced by OpenAI.

# %%
from openai import OpenAI
client = OpenAI(base_url="http://127.0.0.1:1234/v1", api_key="not-needed")

response = client.responses.create(
    model = 'local-model',
    input = 'hello, how are you? Please introduce yourself very briefly, in one or two sentences only,' \
    'no need to explain anything else or elaborate more after your introduction. Stop after those 1 or 2 sentences',
)

# %%
from IPython.display import display, Markdown

display(Markdown(response.output_text))
# Out:
# I am Gemma 4, a Large Language Model with open weights, developed by Google DeepMind.

# %% [markdown]
# We can also ask the model what type of tasks can perform and specific capabilities

# %%
from openai import OpenAI
client = OpenAI(base_url="http://127.0.0.1:1234/v1", api_key="not-needed")

response = client.responses.create(
    model = 'local-model',
    input = 'Please give me two examples of tasks you can perform and tell me if you can classify images',
)

# %%
from IPython.display import display, Markdown

display(Markdown(response.output_text))
# Out:
# As a Large Language Model, I can perform a wide variety of tasks based on my ability to process and generate human language. Here are two examples:
#
# **1. Explaining Complex Concepts:**
# If you provide me with a technical subject, a scientific theory, or a philosophical idea (like quantum entanglement or behavioral economics), I can break it down and explain it to you using analogies, simpler language, or tailored detail levels suitable for a beginner or an expert.
#
# **2. Creative Content Generation:**
# I can generate various forms of original writing, including poems in a specific style, short stories based on simple prompts (e.g., "a lonely astronaut finds a glowing plant"), scripts for videos, or outlines for essays.
#
# ***
#
# ### Can I Classify Images?
#
# **Yes, if you provide me with the image, I can process it and perform classification.**
#
# Because I am a multimodal model (Gemma 4), I can take an image as input and perform tasks such as:
#
# *   **Classification:** Telling you what the main object is (e.g., "This image contains a golden retriever").
# *   **Captioning:** Writing a descriptive sentence or paragraph about what is happening in the image.
# *   **Object Detection:** Identifying specific items within a scene (e.g., "There is a cup, three books, and a laptop on the desk").
#
# So, while I am fundamentally a text generator, my ability to integrate visual input allows me to perform image-based cognitive tasks as well.

# %% [markdown]
# ## Using an Image as Context
#
# There are several ways to interact with the client and use an image as context. They are discussed in the OpenAI platform [documentation](https://platform.openai.com/docs/guides/images-vision?format=base64-encoded#analyze-images). LMStudio inherits this behaviour. Keep in mind the model in use would need to support the task of interest. As we saw in the cell above, we could execute the following code but the model would fail at the specific task

# %%
from openai import OpenAI
client = OpenAI(base_url="http://127.0.0.1:1234/v1", api_key="not-needed")

# %%
import base64
# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")
# Path to your image
#image_path = "./img/00_cat.jpg"
image_path = "./img/0_uyPv5FeFHvOimMKn.jpg"

# Getting the Base64 string
base64_image = encode_image(image_path)


response = client.responses.create(
    model = 'qwen/qwen3.5-9b:2',
    input=[
        {
            "role": "user",
            "content": [
                { "type": "input_text", "text": "what's in this image? Any known character? Is it from Duken Nuken? If so, support your answer with details." },
                {
                    "type": "input_image",
                    "image_url": f"data:image/jpeg;base64,{base64_image}",
                },
            ],
        }
    ],
)

# %% [markdown]
# Only to exemplify the identification or classification of images, we can consume OpenAI directly to accomplish it. To refresh our memory, we repeat the task we did before for text

# %%
from IPython.display import display, Markdown
display(Markdown(response.output_text))
# Out:
# Based on a detailed analysis of the image, here is a breakdown:
#
# ***
#
# ### What's in this image?
#
# The image is a **pixel art portrait** (likely rendered in the style of 8-bit or early 16-bit retro video games).
#
# It depicts a close-up of a male character. The artwork uses distinct, blocky pixels to build the form.
#
# **Key Visual Details:**
# *   **Subject:** A mature male character, possibly with brown or tanned skin.
# *   **Expression:** The expression is highly intense, serious, stern, and possibly worried or angry. His brow is furrowed, suggesting strong emotion.
# *   **Style:** The pixelation gives it a distinct vintage video game aesthetic.
# *   **Framing:** It is tightly cropped, focusing entirely on the head and neck area.
#
# ### Any known character?
#
# The image depicts a specific character from a pixel art work, but **without additional context (such as the game it is taken from, clothing, or body type), this specific character cannot be definitively identified to me.**
#
# He is clearly meant to portray a figure of gravity or importance within his source material.
#
# ### Is it from Duken Nuken? If so, support your answer with details.
#
# **I cannot confirm that this character is from "Duken Nuken" based solely on the visual evidence provided.**
#
# While the pixel art style *could* match many indie or retro games, there is no visual detail (such as unique markings, background elements, clothing fragments, or accessories) that immediately links this portrait to a specific Intellectual Property like "Duken Nuken."
#
# **To support an answer regarding its origin, I would need confirmation on:**
# 1.  The game or series *Duken Nuken* belongs to.
# 2.  Whether this character is known by the name or is a primary antagonist/protagonist in that work.
#
# **In summary:** The image is a highly stylized, intense pixel art portrait of a male character. While it possesses the aesthetic quality to belong to an obscure or independent title like "Duken Nuken," visual identification alone is insufficient to make that connection.

# %%
import sys
sys.path.append('../../05_src/')

# %%
from dotenv import load_dotenv
load_dotenv('../../05_src/.secrets')
# Out:
# True

# %%
import os
from openai import OpenAI
client = OpenAI(base_url='https://k7uffyg03f.execute-api.us-east-1.amazonaws.com/prod/openai/v1', 
                api_key='any value',
                default_headers={"x-api-key": os.getenv('API_GATEWAY_KEY')})

response = client.responses.create(
    model = 'gpt-4o-mini',
    input = 'Hello world!'
    
)

print(response.output_text)
# Out:
# Hello! How can I assist you today?

# %% [markdown]
# Now that the `client` varaible is created, we can use it for a different type of response we are looking for

# %%
import base64
# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")
# Path to your image
#image_path = "./img/00_cat.jpg"
image_path = "./img/0_uyPv5FeFHvOimMKn.jpg"

# Getting the Base64 string
base64_image = encode_image(image_path)


response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        {
            "role": "user",
            "content": [
                #{ "type": "input_text", "text": "what's in this image?" },
                { "type": "input_text", "text": "what's in this image? Any known character? Is it from Duken Nuken? If so, support your answer with details." },
                {
                    "type": "input_image",
                    "image_url": f"data:image/jpeg;base64,{base64_image}",
                },
            ],
        }
    ],
)

# %%
from IPython.display import display, Markdown
display(Markdown(response.output_text))
# Out:
# The image you provided appears to feature Duke Nukem, a well-known character from the video game series of the same name. Duke Nukem is characterized by his muscular build, tough demeanor, and his iconic catchphrases.
#
# In the original "Duke Nukem" games, particularly the side-scrolling platformers and the later 3D titles, Duke often takes on alien invaders and other threats while displaying a satirical attitude. His pixelated representation aligns with the style of early video games, especially from the 1990s.
#
# The character is famous for his brash personality and action-hero archetype, making him a staple in gaming culture. This particular image likely captures a moment from one of his earlier games, emphasizing the distinctive pixel art style that was popular at the time.

# %% [markdown]
# ## Testing local model for images

# %%
import base64
# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")
# Path to your image
image_path = "./img/00_cat.jpg"

# Getting the Base64 string
base64_image = encode_image(image_path)


response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        {
            "role": "user",
            "content": [
                { "type": "input_text", "text": "what's in this image?" },
                {
                    "type": "input_image",
                    "image_url": f"data:image/jpeg;base64,{base64_image}",
                },
            ],
        }
    ],
)
